# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PIL import Image
import requests
import io 
import base64
import numpy as np


url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

# %%
import io 
import base64
buffer = io.BytesIO()
image.save(buffer, format="JPEG")
out = base64.b64encode(buffer.getvalue()).decode()

# %%
embeddings = requests.post("http://localhost:5001/embed", json={
    "prompts": [
        base64.b64encode(buffer.getvalue()).decode(),
        base64.b64encode(buffer.getvalue()).decode(),
    ],
    "modality": "image", 
}).json()

np.array(embeddings).shape
# Out:
# (2, 512)

# %%
from manifest import Manifest 
manifest = Manifest(client_name="huggingface", client_connection="http://127.0.0.1:5001")

# %%
out = manifest.embed(["horse"], modality="text")

# %%
out
# Out:
# [[0.06388360261917114,
#   -0.12784704566001892,
#   -0.1811073124408722,
#   0.1843118667602539,
#   -0.2008025050163269,
#   0.15624260902404785,
#   -0.13006800413131714,
#   -1.0695436000823975,
#   -0.4048464894294739,
#   0.3602138161659241,
#   -0.2635647654533386,
#   -0.4461318850517273,
#   0.05129504203796387,
#   0.18254610896110535,
#   0.30104246735572815,
#   0.022061526775360107,
#   0.4108296036720276,
#   0.08453691005706787,
#   -0.16222763061523438,
#   0.03396545350551605,
#   0.5115214586257935,
#   0.10445486754179001,
#   0.007051795721054077,
#   0.1469556987285614,
#   -0.422476589679718,
#   -0.11328905820846558,
#   -0.3804411292076111,
#   0.40952837467193604,
#   -0.025833167135715485,
#   0.4027453660964966,
#   -0.0951499193906784,
#   -0.125650092959404,
#   -0.06016897037625313,
#   0.3867354989051819,
#   -0.061980217695236206,
#   0.07894034683704376,
#   -0.1360994279384613,
#   0.3280862867832184,
#   -0.09309475123882294,
# ...
